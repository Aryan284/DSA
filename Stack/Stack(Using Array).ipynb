# %%
def push(stack):
    while True:
        print("-1 to break")
        n = int(input("Enter the number want to push: "))
        if n == -1:
            break
        stack.append(n)
    return stack
def pop(stack):
    if stack == []:
        print("No element to pop")
        return stack, None
    else:
         popped_element = stack.pop()
    return stack, popped_element 
def top(stack):
    if stack == []:
        print("Stack is empty")
        return stack
    else:
        x = stack[-1]
        return x
def isEmpty(stack):
    if stack == []:
        print("Stack is Empty")
        return True
    else:
        return False


if __name__=="__main__":
    stack = []
    while True:
        print("-1 to exit")
        print("1. Push in stack")
        print("2. Display stack")
        print("3. Pop in stack")
        print("4. Top of the stack")
        print("5. Postfix evaluation")
        print("6. Empty function")
        ch = int(input("Enter your choice: "))
        if ch == 1:
            stack = push(stack)
        elif ch == 2:
            print("Stack:", stack)
        elif ch == 3:
             stack, popped_element = pop(stack)
             print("Popped element is", popped_element)

        elif ch == 4:
            i = top(stack)
            print("Top Element:", i)
        elif ch == 5:
            stack = infix_to_postfix(stack)
        elif ch == 6:
            stack = isEmpty(stack)
        else:
            break
